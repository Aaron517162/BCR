# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaron517162/BCR/blob/main/Python_Referesher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Text

# %% [markdown]
# Text

# %%
# create a labed storage basket and put a number inside
tomato_price = 150
pepper_price = 80

# pull the value out of the basket
print (tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# change tomato price

# %%
tomato_price =100
print (tomato_price)
# Out:
# 100

# %% [markdown]
# ML Anchor

# %%
# --- The CLUES (Features ground as X) ---
rainfall_mm = 45.2       # clue 1
bags_available = 100     # Clue 2

# --- The GOAL (Target labeled as y) ---
predicated_price = 3200  # what our AI calculates

print ("inputs (x):",rainfall_mm,"mm rain,", bags_available, "bags.")
print('output (y):', predicated_price, "LRD,")
# Out:
# inputs (x): 45.2 mm rain, 100 bags.
# output (y): 3200 LRD,

# %% [markdown]
# Understanding Print

# %%
Liberia =1847
print ("Liberia")
print (Liberia)
# Out:
# Liberia
# 1847

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price=150.50
items_name = "tomatoes"
stall_is_open = True

print (type(quantity))
print (type(price))
print (type(items_name))
print (type(stall_is_open))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
