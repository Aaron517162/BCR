# %% [markdown]
# <a href="https://colab.research.google.com/github/Aaron517162/BCR/blob/main/Try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
A=25
B=30
C=40
D=A+B+C
print (D)
# Out:
# 95

# %% [markdown]
# Introduction

# %%
Greeting = "Hello John"
print (Greeting)
# Out:
# Hello John
